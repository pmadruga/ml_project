# %%
import seaborn as sns
from matplotlib import dates
import matplotlib.pyplot as plt
import pandas as pd
import warnings
from sklearn.preprocessing import StandardScaler
import tabulate
warnings.filterwarnings('ignore')
# sns.set(font_scale=5.5)
sns.set(style="darkgrid")
sns.set(rc={'figure.figsize':(11.7,8.27)}, font_scale=1.5)
df_hrv = pd.read_csv("../data/original/HeartRateVariabilitySDNN.csv")
# df_hrv.head()

# df_new = pd.DataFrame(index=df_hrv.index)
# df_new['date'] = pd.to_datetime(df_hrv['creationDate'])
# df_new['hrv'] = df_hrv['value']
# new_date = []


# for (index, row) in df_new.iterrows():
#     new_date.append(np.datetime64('2005-02-25T03:30'))


# df_new['new date'] = new_date 
# df_new['new date'] = df_new['new date'].values.astype(float)  
# df_new.head()

# from pandas.plotting import autocorrelation_plot

# %%
def parse_date(x):
    return pd.datetime.strptime(x[:-6],'%Y-%m-%d %H:%M:%S')

series = pd.read_csv('../data/original/HeartRateVariabilitySDNN.csv', header=0, index_col=5, parse_dates=[5], squeeze=True, date_parser=parse_date)

df_stuff['value'] = series['value'].resample('H').mean().interpolate()
df_stuff['creationDate'] = series.index
df_yarr = pd.DataFrame(df_stuff)
df_yarr = df_yarr.reset_index()
# df_yarr.columns = ['creationDate', 'value']

# df_yarr.head()

for (index, row) in df_yarr.iterrows():
    print(type(row['creationDate']))
    print((row['creationDate']).hour)
    break
# Out:
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# 9

# %%
df_hrv_filtered = df_yarr

# convert from string to datetime
# df_hrv_filtered['creationDate'] = pd.to_datetime(df_hrv_filtered['creationDate'])
# mean per day
# df_hrv_final = df_hrv_filtered.groupby(df_hrv_filtered['creationDate'].dt.date).mean()

df_hrv_filtered.head()
# Out:
#                 creationDate    value
# 0  2018-01-16 09:00:00+02:00  38.7547
# 1  2018-01-16 10:00:00+02:00  36.4794
# 2  2018-01-16 11:00:00+02:00  34.2041
# 3  2018-01-16 12:00:00+02:00  31.9287
# 4  2018-01-16 13:00:00+02:00  29.6534

# %%
scaler = StandardScaler()
hrv_merged = pd.DataFrame()

def at_work(row):
#     print(row['creationDate'].hour)
    derp = row['creationDate'].hour
    hour = row['creationDate'].hour
    weekday = row['creationDate'].isoweekday()
    
    if((hour >= 9 and hour <17) and weekday < 6):
        # print(pd.to_datetime(row['creationDate']), (weekday))
        return 1
    return 0
    
# winter is from 1st of November to 1st of April
def is_winter(row):
    month = pd.to_datetime(row['creationDate'], format='%d/%m').month
    
    if(month >= 10 or month < 4):
        return 1
    return 0

def is_higher_than_mean(row):
    mean = 41.25
    if row.value > mean:
        return 1
    return 0

def get_hour_of_day(row):
    hour = pd.to_datetime(row['creationDate']).hour
    return hour

def get_day_of_week(row):
    weekday = pd.to_datetime(row['creationDate']).isoweekday()
    return weekday

def get_time_of_day(row):
    hour = pd.to_datetime(row['creationDate']).hour
    
    if((hour >= 6 and hour <12)):
        return 1
    return 0
    
    
hrv_merged['date'] = df_hrv_filtered['creationDate']
hrv_merged['HRV (SDNN)'] = df_hrv_filtered['value']

work_hours = []
winter_time = []
above_mean = []
hour_of_day = []
day_of_week = []
time_of_day = [] # is morning or afternoon



for (index, row) in df_hrv_filtered.iterrows():

        
    work_hours.append(at_work(row))
#     winter_time.append(is_winter(row))
    above_mean.append(is_higher_than_mean(row))
    hour_of_day.append(get_hour_of_day(row))
    day_of_week.append(get_day_of_week(row))
    time_of_day.append(get_time_of_day(row))
    if (row['value'] > 150):
        df_hrv_filtered.drop(index, inplace=True)
    
hrv_merged['Is at Work (binary)'] = work_hours
hrv_merged['Is Above Mean Value'] = above_mean
hrv_merged['Hour of Day'] = hour_of_day
hrv_merged['Day of Week'] = day_of_week
hrv_merged['Is Morning'] = time_of_day
hrv_merged['new date'] = hrv_merged['date'].astype(np.int64).values.reshape(-1,1)

hrv_merged.to_csv('../data/hrv_shaped.csv')

sns.heatmap(hrv_merged.corr(),
            vmin=-1,
            cmap='coolwarm',
            annot=True);

hrv_merged.head()

# hrv_copy = hrv_merged.set_index('date')
# hrv_scaled = scaler.fit_transform(hrv_copy)

# print(tabulate(hrv_summary, tablefmt="pipe", headers="keys"))
# results.head()

# hrv_copy = hrv_merged.set_index('date')

# hrv_copy.head()
# hrv_scaled = scaler.fit_transform(hrv_copy)
# # hrv_summary




# sx = sns.lineplot(x="date", y="HRV (SDNN)", data=hrv_merged)
# sx.set(xlim = (pd.to_datetime('2018-01-13'), pd.to_datetime('2019-10-31')))

# sx.set_title('HRV', fontsize=20)

# for item in sx.get_xticklabels():
#     item.set_rotation(45)
# hrv_merged.hist()

# new_pd = pd.DataFrame(hrv_scaled)

# new_pd.head()
# hrv_merged = hrv_merged.set_index('date')
# hrv_scaled = scaler.fit_transform(hrv_copy)
# df_hrv_scaled = pd.DataFrame(hrv_scaled)
# df_hrv_scaled.head(50)

# hrv_copy.head(10)

# fig = sx.get_figure()
# fig.savefig("../report/images/dataset_3.png")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-836-a62574d9d7f5> in <module>
#      56
#      57 for (index, row) in df_hrv_filtered.iterrows():
# ---> 58     work_hours.append(at_work(row['creationDate'].hour, row['creationDate'].isoweekday()))
#      59 #     winter_time.append(is_winter(row))
#      60     above_mean.append(is_higher_than_mean(row))
#
# AttributeError: 'str' object has no attribute 'hour'

# %%
# hrv_merged['HRV (SDNN)'].hist()
sns.distplot(hrv_merged['HRV (SDNN)'])

# %%
ax = sns.scatterplot(x=hrv_merged['date'], y=hrv_merged['HRV (SDNN)'], data=hrv_merged)
ax.set(xlim = (pd.to_datetime('2018-01-13'), pd.to_datetime('2019-10-31')))
for item in ax.get_xticklabels():
    item.set_rotation(45)

# %%
hrv_copy = hrv_merged.set_index('date')


hrv_scaled = scaler.fit_transform(hrv_copy)

df_hrv_scaled = pd.DataFrame(hrv_scaled)
df_hrv_scaled.columns = ['HRV', 'At Work', 'Above Mean', 'Hour of day', 'Day of week', 'Is morning', 'new date']
# hrv_copy.head()
# df_hrv_scaled.corr() // It's the same as non-scaled values

df_hrv_scaled.head()
# Out:
#         HRV   At Work  Above Mean  Hour of day  Day of week  Is morning  \
# 0 -0.564675  1.148219   -0.874729    -0.942315    -0.888043    1.537732
# 1  0.246422  1.148219    1.143211    -0.942315    -0.888043    1.537732
# 2 -0.884823  1.148219   -0.874729     0.000000    -0.888043   -0.650308
# 3  0.010991 -0.870914    1.143211     1.319241    -0.888043   -0.650308
# 4 -0.012547  1.148219   -0.874729    -0.942315     0.201695    1.537732
#
#    new date
# 0 -1.733713
# 1 -1.733696
# 2 -1.732652
# 3 -1.731274
# 4 -1.723736

# %% [raw]
# hrv_merged.index = pd.to_datetime(hrv_merged['date'])
# # pd.to_datetime(data['date'])
#
# type(hrv_merged.index[0])
#
# # X = (hrv_merged['date'] -  hrv_merged['date'][0])
# Y = hrv_merged.index
# Ys = scaler.fit_transform(pd.DataFrame(Y))

# %% [markdown]
# # Linear regression

# %%
from sklearn import linear_model, model_selection, metrics, preprocessing
import numpy as np

# %% [markdown]
# 1. Split test and train data sets
# 2. Determine alpha interval
# 3. Type cohercion

# %%
# stuff = hrv_merged['date'].astype(np.int64).values.reshape(-1,1)
X = df_hrv_scaled['Above Mean'].values.reshape(-1,1)

# poly_features = preprocessing.PolynomialFeatures(degree=2)
# X = poly_features.fit_transform(X_raw)

y = df_hrv_scaled['HRV']

n_alphas = 100
alphas = np.logspace(-10, 10, n_alphas)

X_train, X_test, y_train, y_test = model_selection.train_test_split(X, y, test_size = 0.20)

# print(stuff)


# hrv_merged['HRV (SDNN)'].describe()

# sns.lineplot(data=df_hrv_scaled, y=df_hrv_scaled['HRV'], x=df_hrv_scaled['new date'])
# stuff.flatten().shape
# df_hrv_scaled.shape

# from pandas.plotting import lag_plot

# lag_plot(hrv_merged[['date', 'HRV (SDNN)']])

# %%
## Non-regularized linear regression
linreg = linear_model.LinearRegression().fit(X_train, y_train)
print('score: ', linreg.score(X_test, y_test))

y_pred_linreg = linreg.predict(X_test)
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred_linreg)))
# linreg.score()


# plt.scatter(X_test, y_test,  color='gray')
# plt.plot(X_test, y_pred, color='red', linewidth=2)
# plt.show()
# Out:
# score:  0.48387314810823445
# Root Mean Squared Error: 0.7964061854034649

# %% [markdown]
# ## Regularized linear regression

# %%
ridgeCV = linear_model.RidgeCV(alphas=alphas, cv=10)
ridgeCV.fit(X_train,y_train)

# print(X_test)

print('score', ridgeCV.score(X_test, y_test))
print('coef', ridgeCV.coef_)
print('intercept', ridgeCV.intercept_)
print('alpha',ridgeCV.alpha_)

y_pred_ridge = ridgeCV.predict(X_test)

df_actual_vs_pred = []
df_actual_vs_pred = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred_ridge.flatten() })
df_actual_vs_pred.head()

sns.lineplot(data=df_actual_vs_pred)

# df_actual_vs_pred.describe()
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred_ridge)))


# df1 = df_actual_vs_pred.head(25)
# df1.plot(kind='bar',figsize=(16,10))
# plt.grid(which='major', linestyle='-', linewidth='0.5', color='green')
# plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
# plt.show()
# Out:
# score 0.4828863333545781
# coef [0.73809001]
# intercept -0.021413411463361426
# alpha 20.565123083486515
# Root Mean Squared Error: 0.7971671708804213

# %%
## NOTE: THESE VALUES HAVE TO BE SCALED

coefs = []
for a in alphas:
    ridge = linear_model.Ridge(alpha=a, fit_intercept=True)
    ridge.fit(X_train, y_train)
    coefs.append(ridge.coef_)
    
# print(coefs, alphas)

ax = plt.gca()

ax.plot(alphas, coefs)
ax.set_xscale('log')
# ax.set_xlim(ax.get_xlim()[::-1])  # reverse axis
plt.xlabel('alpha')
plt.ylabel('weights')
plt.title('Ridge coefficients as a function of the regularization')
plt.axis('tight')
plt.show()

# %%
## NOTE: THESE VALUES SHOULD _NOT_ BE SCALED

# alphas = list(range(0, 10, 0.1))

# print(alphas)

coefs = []
error_train = []
error_test = []

for a in alphas:
#     print(a)
    model = linear_model.Ridge(alpha=a)
    model.fit(X_train,y_train)
    scores = model_selection.cross_val_score(model, X, y, scoring='neg_mean_squared_error', cv = 10)
#     score_test = model_selection.cross_val_score(model, X_test, y_test, scoring='neg_mean_squared_error', cv = 10)
#     score_test = model.score(X_test, y_test)
#     print(model.coef_)
    y_pred = model.predict(X_test)
#     print(y_pred)
#     print(a, model.coef_.mean())
    score_test = np.sqrt(metrics.mean_squared_error(y_test, y_pred))
    error_train.append(np.sqrt(-scores).mean())
    error_test.append(score_test)
    
#     print(a, (np.sqrt(-scores).mean()), score_test)
    

df_errors = pd.DataFrame({'lambda': alphas, 'Training Error': error_train, 'Test Error': error_test})
df_errors.columns = ['lambda', 'Training Error', 'Test Error']  
df_errors = df_errors.set_index(-np.log10(alphas))
print(-np.log10(1.29154967e+01))
# df_errors = df_errors.set_index(alphas)



# df_errors.head()
# Out:
# -1.1111111127873985

# %%
from matplotlib.colors import LogNorm

ex = sns.lineplot(data=df_errors[['Training Error', 'Test Error']])
ex.set_title('Best Lambda selection')
ex.set(xlabel='-log10(λ)', ylabel='Error (RMSE)')


# ex.set(xlim = (0,20))
# Out:
# [Text(0, 0.5, 'Error (RMSE)'), Text(0.5, 0, '-log10(λ)')]

# %% [markdown]
# ## Test data set (predictions)

# %%
# y_pred = model.predict(X_test)

df_actual_vs_pred = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred_ridge.flatten() })
df_actual_vs_pred.head()

# print(y_pred_ridge)

# sns.lineplot(data=df_actual_vs_pred['Actual'])

print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred_ridge))  
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred_ridge))  
print('Root Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred_ridge))

# df_actual_vs_pred.head(50)

df1 = df_actual_vs_pred.head(10)
df1.plot(kind='bar',figsize=(16,10))
plt.grid(which='major', linestyle='-', linewidth='0.5', color='green')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.show()
# Out:
# Mean Absolute Error: 0.9518180166725209
# Mean Squared Error: 1.9984606960560494
# Root Mean Squared Error: 1.9984606960560494

# %%
print(X_train.shape)
print(y_train.shape)

# plt.scatter(X_train, y_train,  color='gray')
# plt.plot(X_train, y_pred, color='red', linewidth=2)
# plt.show()
# Out:
# (745, 1)
# (745,)

# %%
derp = linear_model.LassoCV(cv=10).fit(X_train, y_train)

print(derp.alpha_)
# Display results
m_log_alphas = -np.log10(derp.alphas_)

plt.figure()
plt.plot(m_log_alphas, derp.mse_path_, '.')
# Out:
# 0.0007733544622052606
# [<matplotlib.lines.Line2D at 0x11edcb490>,
#  <matplotlib.lines.Line2D at 0x1214789d0>,
#  <matplotlib.lines.Line2D at 0x11edcb850>,
#  <matplotlib.lines.Line2D at 0x11e5f0410>,
#  <matplotlib.lines.Line2D at 0x11e5f09d0>,
#  <matplotlib.lines.Line2D at 0x11e5f00d0>,
#  <matplotlib.lines.Line2D at 0x11e5f0d50>,
#  <matplotlib.lines.Line2D at 0x11e5f0ad0>,
#  <matplotlib.lines.Line2D at 0x11e5f0490>,
#  <matplotlib.lines.Line2D at 0x11e5f0890>]

# %%
values = DataFrame(series.values)
dataframe = concat([values.shift(1), values], axis=1)
dataframe.columns = ['t-1', 't+1']
result = dataframe.corr()
print(result)

# %% [markdown]
# ## Kfolds

# %%
K = 10
CV = model_selection.KFold(n_splits=K,shuffle=True)
# Initialize variable
Error_train = np.empty((0,K))
Error_test = np.empty((0,K))

i = 0 
for train_index, test_index in CV.split(X):
    print('Computing CV fold: {0}/{1}..'.format(i+1,K))

    # extract training and test set for current CV fold
    X_train, y_train = X[train_index,:], y[train_index]
    X_test, y_test = X[test_index,:], y[test_index]
    
    linreg = linear_model.LinearRegression().fit(X_train, y_train)
    print('score: ', linreg.score(X_test, y_test))

    y_pred_linreg = linreg.predict(X_test)
    print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred_linreg)))
    # linreg.score()
    
    
    
    for a in alphas:
    # print(a)
        ridge = linear_model.Ridge(alpha=a)
        ridge.fit(X_train,y_train)
        ridge.score(X_test, y_test)
#         print('score: ', linreg.score(X_test, y_test))
        y_pred_ridge = ridge.predict(X_test)
        
        print('[Ridge] Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred_ridge)))
    
    i+=1
# Out:
# Computing CV fold: 1/10..
# score:  0.6143262027247028
# Root Mean Squared Error: 0.5749496598912627
# [Ridge] Root Mean Squared Error: 0.5749496598912597
# [Ridge] Root Mean Squared Error: 0.574949659891258
# [Ridge] Root Mean Squared Error: 0.5749496598912552
# [Ridge] Root Mean Squared Error: 0.5749496598912508
# [Ridge] Root Mean Squared Error: 0.5749496598912438
# [Ridge] Root Mean Squared Error: 0.5749496598912327
# [Ridge] Root Mean Squared Error: 0.5749496598912148
# [Ridge] Root Mean Squared Error: 0.5749496598911865
# [Ridge] Root Mean Squared Error: 0.5749496598911414
# [Ridge] Root Mean Squared Error: 0.5749496598910696
# [Ridge] Root Mean Squared Error: 0.5749496598909554
# [Ridge] Root Mean Squared Error: 0.5749496598907732
# [Ridge] Root Mean Squared Error: 0.5749496598904833
# [Ridge] Root Mean Squared Error: 0.5749496598900218
# [Ridge] Root Mean Squared Error: 0.5749496598892868
# [Ridge] Root Mean Squared Error: 0.5749496598881165
# [Ridge] Root Mean Squared Error: 0.5749496598862532
# [Ridge] Root Mean Squared Error: 0.5749496598832862
# [Ridge] Root Mean Squared Error: 0.5749496598785618
# [Ridge] Root Mean Squared Error: 0.5749496598710394
# [Ridge] Root Mean Squared Error: 0.5749496598590615
# [Ridge] Root Mean Squared Error: 0.5749496598399895
# [Ridge] Root Mean Squared Error: 0.5749496598096212
# [Ridge] Root Mean Squared Error: 0.5749496597612664
# [Ridge] Root Mean Squared Error: 0.5749496596842718
# [Ridge] Root Mean Squared Error: 0.5749496595616749
# [Ridge] Root Mean Squared Error: 0.5749496593664658
# [Ridge] Root Mean Squared Error: 0.5749496590556379
# [Ridge] Root Mean Squared Error: 0.5749496585607122
# [Ridge] Root Mean Squared Error: 0.5749496577726516
# [Ridge] Root Mean Squared Error: 0.5749496565178385
# [Ridge] Root Mean Squared Error: 0.5749496545198265
# [Ridge] Root Mean Squared Error: 0.5749496513384404
# [Ridge] Root Mean Squared Error: 0.5749496462728101
# [Ridge] Root Mean Squared Error: 0.5749496382069846
# [Ridge] Root Mean Squared Error: 0.5749496253641388
# [Ridge] Root Mean Squared Error: 0.5749496049152788
# [Ridge] Root Mean Squared Error: 0.5749495723563863
# [Ridge] Root Mean Squared Error: 0.5749495205171639
# [Ridge] Root Mean Squared Error: 0.5749494379839479
# [Ridge] Root Mean Squared Error: 0.5749493065917783
# [Ridge] Root Mean Squared Error: 0.5749490974392618
# [Ridge] Root Mean Squared Error: 0.5749487645638918
# [Ridge] Root Mean Squared Error: 0.5749482349240602
# [Ridge] Root Mean Squared Error: 0.5749473925811283
# [Ridge] Root Mean Squared Error: 0.5749460538512198
# [Ridge] Root Mean Squared Error: 0.574943928597154
# [Ridge] Root Mean Squared Error: 0.5749405607650659
# [Ridge] Root Mean Squared Error: 0.5749352391945116
# [Ridge] Root Mean Squared Error: 0.5749268694837031
# [Ridge] Root Mean Squared Error: 0.5749138049742036
# [Ridge] Root Mean Squared Error: 0.5748936656684984
# [Ridge] Root Mean Squared Error: 0.5748632701784734
# [Ridge] Root Mean Squared Error: 0.5748190741772741
# [Ridge] Root Mean Squared Error: 0.5747592084718697
# [Ridge] Root Mean Squared Error: 0.5746899387847297
# [Ridge] Root Mean Squared Error: 0.574643394561357
# [Ridge] Root Mean Squared Error: 0.5747219999953226
# [Ridge] Root Mean Squared Error: 0.5752006419210562
# [Ridge] Root Mean Squared Error: 0.5767364888699776
# [Ridge] Root Mean Squared Error: 0.5807260180079904
# [Ridge] Root Mean Squared Error: 0.5897069674314
# [Ridge] Root Mean Squared Error: 0.607300506601459
# [Ridge] Root Mean Squared Error: 0.6368146885460545
# [Ridge] Root Mean Squared Error: 0.6785210438504278
# [Ridge] Root Mean Squared Error: 0.7279905088566526
# [Ridge] Root Mean Squared Error: 0.7779179680573415
# [Ridge] Root Mean Squared Error: 0.8219183432432492
# [Ridge] Root Mean Squared Error: 0.8568174813977228
# [Ridge] Root Mean Squared Error: 0.8824454552262281
# [Ridge] Root Mean Squared Error: 0.900279882962148
# [Ridge] Root Mean Squared Error: 0.9122486752090724
# [Ridge] Root Mean Squared Error: 0.9200914355249336
# [Ridge] Root Mean Squared Error: 0.9251516631374379
# [Ridge] Root Mean Squared Error: 0.9283843844450721
# [Ridge] Root Mean Squared Error: 0.9304366328267581
# [Ridge] Root Mean Squared Error: 0.9317342876262913
# [Ridge] Root Mean Squared Error: 0.9325527428753189
# [Ridge] Root Mean Squared Error: 0.9330681397346345
# [Ridge] Root Mean Squared Error: 0.9333923711274913
# [Ridge] Root Mean Squared Error: 0.9335962140986029
# [Ridge] Root Mean Squared Error: 0.9337243188015265
# [Ridge] Root Mean Squared Error: 0.9338048059873549
# [Ridge] Root Mean Squared Error: 0.9338553675834568
# [Ridge] Root Mean Squared Error: 0.9338871269857797
# [Ridge] Root Mean Squared Error: 0.9339070748857028
# [Ridge] Root Mean Squared Error: 0.9339196035646308
# [Ridge] Root Mean Squared Error: 0.9339274722621682
# [Ridge] Root Mean Squared Error: 0.9339324141605702
# [Ridge] Root Mean Squared Error: 0.933935517866896
# [Ridge] Root Mean Squared Error: 0.9339374671046848
# [Ridge] Root Mean Squared Error: 0.9339386912906195
# [Ridge] Root Mean Squared Error: 0.9339394601181389
# [Ridge] Root Mean Squared Error: 0.9339399429654404
# [Ridge] Root Mean Squared Error: 0.933940246208096
# [Ridge] Root Mean Squared Error: 0.9339404366535102
# [Ridge] Root Mean Squared Error: 0.9339405562588553
# [Ridge] Root Mean Squared Error: 0.9339406313745271
# [Ridge] Root Mean Squared Error: 0.9339406785493696
# [Ridge] Root Mean Squared Error: 0.9339407081765502
# Computing CV fold: 2/10..
# score:  0.5970459118496899
# Root Mean Squared Error: 0.5352229059114519
# [Ridge] Root Mean Squared Error: 0.5352229059114311
# [Ridge] Root Mean Squared Error: 0.5352229059114186
# [Ridge] Root Mean Squared Error: 0.5352229059113989
# [Ridge] Root Mean Squared Error: 0.5352229059113673
# [Ridge] Root Mean Squared Error: 0.5352229059113172
# [Ridge] Root Mean Squared Error: 0.5352229059112372
# [Ridge] Root Mean Squared Error: 0.5352229059111101
# [Ridge] Root Mean Squared Error: 0.5352229059109074
# [Ridge] Root Mean Squared Error: 0.5352229059105849
# [Ridge] Root Mean Squared Error: 0.5352229059100713
# [Ridge] Root Mean Squared Error: 0.5352229059092535
# [Ridge] Root Mean Squared Error: 0.5352229059079512
# [Ridge] Root Mean Squared Error: 0.5352229059058776
# [Ridge] Root Mean Squared Error: 0.5352229059025762
# [Ridge] Root Mean Squared Error: 0.5352229058973191
# [Ridge] Root Mean Squared Error: 0.5352229058889484
# [Ridge] Root Mean Squared Error: 0.5352229058756198
# [Ridge] Root Mean Squared Error: 0.5352229058543969
# [Ridge] Root Mean Squared Error: 0.5352229058206042
# [Ridge] Root Mean Squared Error: 0.5352229057667965
# [Ridge] Root Mean Squared Error: 0.5352229056811196
# [Ridge] Root Mean Squared Error: 0.5352229055446975
# [Ridge] Root Mean Squared Error: 0.5352229053274752
# [Ridge] Root Mean Squared Error: 0.5352229049815957
# [Ridge] Root Mean Squared Error: 0.5352229044308578
# [Ridge] Root Mean Squared Error: 0.5352229035539274
# [Ridge] Root Mean Squared Error: 0.5352229021576063
# [Ridge] Root Mean Squared Error: 0.5352228999342684
# [Ridge] Root Mean Squared Error: 0.535222896394086
# [Ridge] Root Mean Squared Error: 0.5352228907571159
# [Ridge] Root Mean Squared Error: 0.5352228817814685
# [Ridge] Root Mean Squared Error: 0.5352228674897072
# [Ridge] Root Mean Squared Error: 0.5352228447332011
# [Ridge] Root Mean Squared Error: 0.5352228084984583
# [Ridge] Root Mean Squared Error: 0.535222750802627
# [Ridge] Root Mean Squared Error: 0.5352226589348684
# [Ridge] Root Mean Squared Error: 0.5352225126562301
# [Ridge] Root Mean Squared Error: 0.5352222797413326
# [Ridge] Root Mean Squared Error: 0.5352219088801754
# [Ridge] Root Mean Squared Error: 0.5352213183775861
# [Ridge] Root Mean Squared Error: 0.5352203781640673
# [Ridge] Root Mean Squared Error: 0.5352188811634286
# [Ridge] Root Mean Squared Error: 0.535216497730997
# [Ridge] Root Mean Squared Error: 0.5352127031799642
# [Ridge] Root Mean Squared Error: 0.5352066625694025
# [Ridge] Root Mean Squared Error: 0.5351970477270238
# [Ridge] Root Mean Squared Error: 0.535181747095676
# [Ridge] Root Mean Squared Error: 0.5351574067612341
# [Ridge] Root Mean Squared Error: 0.5351187073199417
# [Ridge] Root Mean Squared Error: 0.5350572318702623
# [Ridge] Root Mean Squared Error: 0.5349597125804357
# [Ridge] Root Mean Squared Error: 0.5348053622649125
# [Ridge] Root Mean Squared Error: 0.5345619354591273
# [Ridge] Root Mean Squared Error: 0.5341802293775737
# [Ridge] Root Mean Squared Error: 0.533587235421668
# [Ridge] Root Mean Squared Error: 0.5326798654736403
# [Ridge] Root Mean Squared Error: 0.5313259017413773
# [Ridge] Root Mean Squared Error: 0.5293901734655753
# [Ridge] Root Mean Squared Error: 0.5268273948421077
# [Ridge] Root Mean Squared Error: 0.5239198483434955
# [Ridge] Root Mean Squared Error: 0.521757213176662
# [Ridge] Root Mean Squared Error: 0.5229246003687261
# [Ridge] Root Mean Squared Error: 0.5318324905469176
# [Ridge] Root Mean Squared Error: 0.553367870082701
# [Ridge] Root Mean Squared Error: 0.5893548727782455
# [Ridge] Root Mean Squared Error: 0.6358167135238384
# [Ridge] Root Mean Squared Error: 0.6847777629093154
# [Ridge] Root Mean Squared Error: 0.7288819113089003
# [Ridge] Root Mean Squared Error: 0.7642588115466711
# [Ridge] Root Mean Squared Error: 0.7903923208188868
# [Ridge] Root Mean Squared Error: 0.8086377862909045
# [Ridge] Root Mean Squared Error: 0.8209050537110573
# [Ridge] Root Mean Squared Error: 0.8289520809020551
# [Ridge] Root Mean Squared Error: 0.8341474609449496
# [Ridge] Root Mean Squared Error: 0.8374678299362613
# [Ridge] Root Mean Squared Error: 0.8395762303810341
# [Ridge] Root Mean Squared Error: 0.8409095905965971
# [Ridge] Root Mean Squared Error: 0.8417506444803253
# [Ridge] Root Mean Squared Error: 0.8422803030365965
# [Ridge] Root Mean Squared Error: 0.8426135185013687
# [Ridge] Root Mean Squared Error: 0.8428230145176723
# [Ridge] Root Mean Squared Error: 0.8429546737555831
# [Ridge] Root Mean Squared Error: 0.8430373949732438
# [Ridge] Root Mean Squared Error: 0.8430893602693954
# [Ridge] Root Mean Squared Error: 0.8431220014977945
# [Ridge] Root Mean Squared Error: 0.843142503313362
# [Ridge] Root Mean Squared Error: 0.8431553799081533
# [Ridge] Root Mean Squared Error: 0.843163467123044
# [Ridge] Root Mean Squared Error: 0.8431685462630439
# [Ridge] Root Mean Squared Error: 0.8431717361635901
# [Ridge] Root Mean Squared Error: 0.8431737395348465
# [Ridge] Root Mean Squared Error: 0.8431749977185651
# [Ridge] Root Mean Squared Error: 0.8431757878978366
# [Ridge] Root Mean Squared Error: 0.8431762841547212
# [Ridge] Root Mean Squared Error: 0.84317659581901
# [Ridge] Root Mean Squared Error: 0.8431767915534644
# [Ridge] Root Mean Squared Error: 0.8431769144804845
# [Ridge] Root Mean Squared Error: 0.8431769916822665
# [Ridge] Root Mean Squared Error: 0.8431770401672479
# [Ridge] Root Mean Squared Error: 0.8431770706172339
# Computing CV fold: 3/10..
# score:  0.6555056979601452
# Root Mean Squared Error: 0.5692246353410761
# [Ridge] Root Mean Squared Error: 0.5692246353410784
# [Ridge] Root Mean Squared Error: 0.5692246353410796
# [Ridge] Root Mean Squared Error: 0.5692246353410817
# [Ridge] Root Mean Squared Error: 0.5692246353410848
# [Ridge] Root Mean Squared Error: 0.5692246353410899
# [Ridge] Root Mean Squared Error: 0.5692246353410981
# [Ridge] Root Mean Squared Error: 0.569224635341111
# [Ridge] Root Mean Squared Error: 0.5692246353411314
# [Ridge] Root Mean Squared Error: 0.5692246353411642
# [Ridge] Root Mean Squared Error: 0.5692246353412163
# [Ridge] Root Mean Squared Error: 0.5692246353412992
# [Ridge] Root Mean Squared Error: 0.5692246353414311
# [Ridge] Root Mean Squared Error: 0.5692246353416415
# [Ridge] Root Mean Squared Error: 0.5692246353419761
# [Ridge] Root Mean Squared Error: 0.569224635342509
# [Ridge] Root Mean Squared Error: 0.5692246353433575
# [Ridge] Root Mean Squared Error: 0.5692246353447088
# [Ridge] Root Mean Squared Error: 0.5692246353468603
# [Ridge] Root Mean Squared Error: 0.5692246353502861
# [Ridge] Root Mean Squared Error: 0.5692246353557409
# [Ridge] Root Mean Squared Error: 0.5692246353644265
# [Ridge] Root Mean Squared Error: 0.5692246353782565
# [Ridge] Root Mean Squared Error: 0.5692246354002777
# [Ridge] Root Mean Squared Error: 0.5692246354353416
# [Ridge] Root Mean Squared Error: 0.5692246354911733
# [Ridge] Root Mean Squared Error: 0.5692246355800732
# [Ridge] Root Mean Squared Error: 0.5692246357216272
# [Ridge] Root Mean Squared Error: 0.5692246359470211
# [Ridge] Root Mean Squared Error: 0.5692246363059125
# [Ridge] Root Mean Squared Error: 0.5692246368773698
# [Ridge] Root Mean Squared Error: 0.5692246377872936
# [Ridge] Root Mean Squared Error: 0.569224639236155
# [Ridge] Root Mean Squared Error: 0.569224641543166
# [Ridge] Root Mean Squared Error: 0.5692246452166151
# [Ridge] Root Mean Squared Error: 0.5692246510658737
# [Ridge] Root Mean Squared Error: 0.5692246603797735
# [Ridge] Root Mean Squared Error: 0.5692246752107079
# [Ridge] Root Mean Squared Error: 0.5692246988272001
# [Ridge] Root Mean Squared Error: 0.5692247364350126
# [Ridge] Root Mean Squared Error: 0.5692247963266103
# [Ridge] Root Mean Squared Error: 0.5692248917146127
# [Ridge] Root Mean Squared Error: 0.5692250436592264
# [Ridge] Root Mean Squared Error: 0.5692252857499784
# [Ridge] Root Mean Squared Error: 0.5692256716121519
# [Ridge] Root Mean Squared Error: 0.5692262869904198
# [Ridge] Root Mean Squared Error: 0.5692272693220376
# [Ridge] Root Mean Squared Error: 0.5692288397454958
# [Ridge] Root Mean Squared Error: 0.5692313562006821
# [Ridge] Root Mean Squared Error: 0.569235403376205
# [Ridge] Root Mean Squared Error: 0.5692419495658396
# [Ridge] Root Mean Squared Error: 0.5692526308040688
# [Ridge] Root Mean Squared Error: 0.569270289666664
# [Ridge] Root Mean Squared Error: 0.5693000490674291
# [Ridge] Root Mean Squared Error: 0.5693515568960398
# [Ridge] Root Mean Squared Error: 0.569443866670818
# [Ridge] Root Mean Squared Error: 0.5696163271395118
# [Ridge] Root Mean Squared Error: 0.5699530765699756
# [Ridge] Root Mean Squared Error: 0.5706373622467036
# [Ridge] Root Mean Squared Error: 0.5720667241302757
# [Ridge] Root Mean Squared Error: 0.5750753803420074
# [Ridge] Root Mean Squared Error: 0.5812891552587363
# [Ridge] Root Mean Squared Error: 0.5934760277327733
# [Ridge] Root Mean Squared Error: 0.6153454948732336
# [Ridge] Root Mean Squared Error: 0.6499590227842326
# [Ridge] Root Mean Squared Error: 0.6969778414645366
# [Ridge] Root Mean Squared Error: 0.7512816682135071
# [Ridge] Root Mean Squared Error: 0.8051326357929619
# [Ridge] Root Mean Squared Error: 0.8520556938751367
# [Ridge] Root Mean Squared Error: 0.8890059936910939
# [Ridge] Root Mean Squared Error: 0.9160173464065392
# [Ridge] Root Mean Squared Error: 0.9347608988195453
# [Ridge] Root Mean Squared Error: 0.947317281791707
# [Ridge] Root Mean Squared Error: 0.9555358139788956
# [Ridge] Root Mean Squared Error: 0.9608347459504788
# [Ridge] Root Mean Squared Error: 0.9642184607308842
# [Ridge] Root Mean Squared Error: 0.9663659664055817
# [Ridge] Root Mean Squared Error: 0.9677236154971033
# [Ridge] Root Mean Squared Error: 0.9685798161180545
# [Ridge] Root Mean Squared Error: 0.9691189447243626
# [Ridge] Root Mean Squared Error: 0.969458090830353
# [Ridge] Root Mean Squared Error: 0.9696713048140178
# [Ridge] Root Mean Squared Error: 0.9698052964187455
# [Ridge] Root Mean Squared Error: 0.96988948139466
# [Ridge] Root Mean Squared Error: 0.9699423655648267
# [Ridge] Root Mean Squared Error: 0.9699755837115931
# [Ridge] Root Mean Squared Error: 0.9699964477850805
# [Ridge] Root Mean Squared Error: 0.9700095518633042
# [Ridge] Root Mean Squared Error: 0.97001778193452
# [Ridge] Root Mean Squared Error: 0.9700229507885507
# [Ridge] Root Mean Squared Error: 0.9700261970305823
# [Ridge] Root Mean Squared Error: 0.9700282357853265
# [Ridge] Root Mean Squared Error: 0.9700295161906664
# [Ridge] Root Mean Squared Error: 0.9700303203256696
# [Ridge] Root Mean Squared Error: 0.970030825347123
# [Ridge] Root Mean Squared Error: 0.9700311425158017
# [Ridge] Root Mean Squared Error: 0.9700313417071679
# [Ridge] Root Mean Squared Error: 0.9700314668052269
# [Ridge] Root Mean Squared Error: 0.9700315453704836
# [Ridge] Root Mean Squared Error: 0.9700315947117664
# [Ridge] Root Mean Squared Error: 0.9700316256995346
# Computing CV fold: 4/10..
# score:  0.6234551736753697
# Root Mean Squared Error: 0.4858158768985295
# [Ridge] Root Mean Squared Error: 0.4858158768985013
# [Ridge] Root Mean Squared Error: 0.48581587689848493
# [Ridge] Root Mean Squared Error: 0.48581587689845857
# [Ridge] Root Mean Squared Error: 0.4858158768984166
# [Ridge] Root Mean Squared Error: 0.48581587689834976
# [Ridge] Root Mean Squared Error: 0.4858158768982434
# [Ridge] Root Mean Squared Error: 0.48581587689807415
# [Ridge] Root Mean Squared Error: 0.48581587689780437
# [Ridge] Root Mean Squared Error: 0.48581587689737504
# [Ridge] Root Mean Squared Error: 0.48581587689669137
# [Ridge] Root Mean Squared Error: 0.4858158768956028
# [Ridge] Root Mean Squared Error: 0.48581587689386924
# [Ridge] Root Mean Squared Error: 0.4858158768911092
# [Ridge] Root Mean Squared Error: 0.4858158768867143
# [Ridge] Root Mean Squared Error: 0.4858158768797165
# [Ridge] Root Mean Squared Error: 0.48581587686857386
# [Ridge] Root Mean Squared Error: 0.48581587685083183
# [Ridge] Root Mean Squared Error: 0.48581587682258137
# [Ridge] Root Mean Squared Error: 0.48581587677759863
# [Ridge] Root Mean Squared Error: 0.4858158767059735
# [Ridge] Root Mean Squared Error: 0.48581587659192593
# [Ridge] Root Mean Squared Error: 0.48581587641033
# [Ridge] Root Mean Squared Error: 0.4858158761211781
# [Ridge] Root Mean Squared Error: 0.4858158756607662
# [Ridge] Root Mean Squared Error: 0.4858158749276606
# [Ridge] Root Mean Squared Error: 0.48581587376034885
# [Ridge] Root Mean Squared Error: 0.48581587190165865
# [Ridge] Root Mean Squared Error: 0.4858158689420986
# [Ridge] Root Mean Squared Error: 0.48581586422964224
# [Ridge] Root Mean Squared Error: 0.4858158567260808
# [Ridge] Root Mean Squared Error: 0.4858158447782925
# [Ridge] Root Mean Squared Error: 0.4858158257540434
# [Ridge] Root Mean Squared Error: 0.48581579546208165
# [Ridge] Root Mean Squared Error: 0.4858157472287694
# [Ridge] Root Mean Squared Error: 0.4858156704278408
# [Ridge] Root Mean Squared Error: 0.48581554813941075
# [Ridge] Root Mean Squared Error: 0.48581535342257837
# [Ridge] Root Mean Squared Error: 0.485815043380676
# [Ridge] Root Mean Squared Error: 0.4858145497122721
# [Ridge] Root Mean Squared Error: 0.48581376366773343
# [Ridge] Root Mean Squared Error: 0.4858125121009925
# [Ridge] Root Mean Squared Error: 0.4858105193502959
# [Ridge] Root Mean Squared Error: 0.4858073465748115
# [Ridge] Root Mean Squared Error: 0.48580229524560836
# [Ridge] Root Mean Squared Error: 0.48579425368956125
# [Ridge] Root Mean Squared Error: 0.48578145328511635
# [Ridge] Root Mean Squared Error: 0.48576108162850645
# [Ridge] Root Mean Squared Error: 0.48572867005903564
# [Ridge] Root Mean Squared Error: 0.4856771272212464
# [Ridge] Root Mean Squared Error: 0.4855952224693913
# [Ridge] Root Mean Squared Error: 0.48546522721253793
# [Ridge] Root Mean Squared Error: 0.48525930089716696
# [Ridge] Root Mean Squared Error: 0.4849340921547804
# [Ridge] Root Mean Squared Error: 0.4844230304858035
# [Ridge] Root Mean Squared Error: 0.48362624996433917
# [Ridge] Root Mean Squared Error: 0.4823999008247516
# [Ridge] Root Mean Squared Error: 0.48055186303931696
# [Ridge] Root Mean Squared Error: 0.4778639352443814
# [Ridge] Root Mean Squared Error: 0.4741884684060643
# [Ridge] Root Mean Squared Error: 0.4697138376848015
# [Ridge] Root Mean Squared Error: 0.46552642453995885
# [Ridge] Root Mean Squared Error: 0.4644601017225452
# [Ridge] Root Mean Squared Error: 0.4715816886584838
# [Ridge] Root Mean Squared Error: 0.492659374270414
# [Ridge] Root Mean Squared Error: 0.5299178005286542
# [Ridge] Root Mean Squared Error: 0.5788614344024348
# [Ridge] Root Mean Squared Error: 0.6305968854904078
# [Ridge] Root Mean Squared Error: 0.6771285708773521
# [Ridge] Root Mean Squared Error: 0.7143636188647369
# [Ridge] Root Mean Squared Error: 0.7418134984857397
# [Ridge] Root Mean Squared Error: 0.7609494207687171
# [Ridge] Root Mean Squared Error: 0.7738023282849265
# [Ridge] Root Mean Squared Error: 0.7822278982359596
# [Ridge] Root Mean Squared Error: 0.7876653354922757
# [Ridge] Root Mean Squared Error: 0.7911394490693543
# [Ridge] Root Mean Squared Error: 0.793345091524238
# [Ridge] Root Mean Squared Error: 0.7947397944292869
# [Ridge] Root Mean Squared Error: 0.795619480873004
# [Ridge] Root Mean Squared Error: 0.7961734443102508
# [Ridge] Root Mean Squared Error: 0.7965219407348281
# [Ridge] Root Mean Squared Error: 0.7967410402651307
# [Ridge] Root Mean Squared Error: 0.7968787334043628
# [Ridge] Root Mean Squared Error: 0.7969652451194866
# [Ridge] Root Mean Squared Error: 0.7970195913654696
# [Ridge] Root Mean Squared Error: 0.7970537280602837
# [Ridge] Root Mean Squared Error: 0.7970751691356651
# [Ridge] Root Mean Squared Error: 0.7970886356379695
# [Ridge] Root Mean Squared Error: 0.7970970933418227
# [Ridge] Root Mean Squared Error: 0.7971024051635742
# [Ridge] Root Mean Squared Error: 0.7971057411965744
# [Ridge] Root Mean Squared Error: 0.7971078363438752
# [Ridge] Root Mean Squared Error: 0.7971091521658629
# [Ridge] Root Mean Squared Error: 0.7971099785437412
# [Ridge] Root Mean Squared Error: 0.7971104975344431
# [Ridge] Root Mean Squared Error: 0.7971108234762461
# [Ridge] Root Mean Squared Error: 0.7971110281774015
# [Ridge] Root Mean Squared Error: 0.7971111567357734
# [Ridge] Root Mean Squared Error: 0.7971112374742093
# [Ridge] Root Mean Squared Error: 0.7971112881803126
# [Ridge] Root Mean Squared Error: 0.7971113200252282
# Computing CV fold: 5/10..
# score:  0.6092327819463197
# Root Mean Squared Error: 0.6861002674632128
# [Ridge] Root Mean Squared Error: 0.6861002674632302
# [Ridge] Root Mean Squared Error: 0.6861002674632405
# [Ridge] Root Mean Squared Error: 0.6861002674632569
# [Ridge] Root Mean Squared Error: 0.6861002674632829
# [Ridge] Root Mean Squared Error: 0.6861002674633244
# [Ridge] Root Mean Squared Error: 0.6861002674633906
# [Ridge] Root Mean Squared Error: 0.6861002674634958
# [Ridge] Root Mean Squared Error: 0.6861002674636633
# [Ridge] Root Mean Squared Error: 0.6861002674639302
# [Ridge] Root Mean Squared Error: 0.6861002674643548
# [Ridge] Root Mean Squared Error: 0.6861002674650313
# [Ridge] Root Mean Squared Error: 0.6861002674661081
# [Ridge] Root Mean Squared Error: 0.6861002674678229
# [Ridge] Root Mean Squared Error: 0.6861002674705535
# [Ridge] Root Mean Squared Error: 0.6861002674749014
# [Ridge] Root Mean Squared Error: 0.6861002674818241
# [Ridge] Root Mean Squared Error: 0.6861002674928471
# [Ridge] Root Mean Squared Error: 0.6861002675103992
# [Ridge] Root Mean Squared Error: 0.6861002675383467
# [Ridge] Root Mean Squared Error: 0.6861002675828474
# [Ridge] Root Mean Squared Error: 0.6861002676537047
# [Ridge] Root Mean Squared Error: 0.6861002677665298
# [Ridge] Root Mean Squared Error: 0.6861002679461794
# [Ridge] Root Mean Squared Error: 0.6861002682322319
# [Ridge] Root Mean Squared Error: 0.686100268687709
# [Ridge] Root Mean Squared Error: 0.6861002694129569
# [Ridge] Root Mean Squared Error: 0.6861002705677569
# [Ridge] Root Mean Squared Error: 0.6861002724065248
# [Ridge] Root Mean Squared Error: 0.6861002753343639
# [Ridge] Root Mean Squared Error: 0.6861002799963118
# [Ridge] Root Mean Squared Error: 0.6861002874194523
# [Ridge] Root Mean Squared Error: 0.6861002992391936
# [Ridge] Root Mean Squared Error: 0.6861003180595705
# [Ridge] Root Mean Squared Error: 0.6861003480269482
# [Ridge] Root Mean Squared Error: 0.6861003957435278
# [Ridge] Root Mean Squared Error: 0.6861004717219165
# [Ridge] Root Mean Squared Error: 0.6861005927012513
# [Ridge] Root Mean Squared Error: 0.6861007853352086
# [Ridge] Root Mean Squared Error: 0.6861010920645767
# [Ridge] Root Mean Squared Error: 0.6861015804686108
# [Ridge] Root Mean Squared Error: 0.686102358156444
# [Ridge] Root Mean Squared Error: 0.6861035964820036
# [Ridge] Root Mean Squared Error: 0.6861055683139295
# [Ridge] Root Mean Squared Error: 0.6861087081989522
# [Ridge] Root Mean Squared Error: 0.6861137082172428
# [Ridge] Root Mean Squared Error: 0.6861216707587888
# [Ridge] Root Mean Squared Error: 0.6861343521602103
# [Ridge] Root Mean Squared Error: 0.6861545515888609
# [Ridge] Root Mean Squared Error: 0.6861867326456016
# [Ridge] Root Mean Squared Error: 0.6862380191594053
# [Ridge] Root Mean Squared Error: 0.6863197959320727
# [Ridge] Root Mean Squared Error: 0.6864502955136942
# [Ridge] Root Mean Squared Error: 0.6866588112873615
# [Ridge] Root Mean Squared Error: 0.686992636861563
# [Ridge] Root Mean Squared Error: 0.687528670012734
# [Ridge] Root Mean Squared Error: 0.6883931738243391
# [Ridge] Root Mean Squared Error: 0.6897960347067745
# [Ridge] Root Mean Squared Error: 0.6920906795769438
# [Ridge] Root Mean Squared Error: 0.6958771190772288
# [Ridge] Root Mean Squared Error: 0.7021664501353666
# [Ridge] Root Mean Squared Error: 0.7125934850119324
# [Ridge] Root Mean Squared Error: 0.7295389409258711
# [Ridge] Root Mean Squared Error: 0.7557723234260287
# [Ridge] Root Mean Squared Error: 0.7931322110479698
# [Ridge] Root Mean Squared Error: 0.8405511435249471
# [Ridge] Root Mean Squared Error: 0.8932208537525563
# [Ridge] Root Mean Squared Error: 0.9444041856437195
# [Ridge] Root Mean Squared Error: 0.9885723015508316
# [Ridge] Root Mean Squared Error: 1.0232002671696014
# [Ridge] Root Mean Squared Error: 1.0484647141047654
# [Ridge] Root Mean Squared Error: 1.0659810839489032
# [Ridge] Root Mean Squared Error: 1.077710916598274
# [Ridge] Root Mean Squared Error: 1.085387115301996
# [Ridge] Root Mean Squared Error: 1.090335967602492
# [Ridge] Root Mean Squared Error: 1.0934960036611472
# [Ridge] Root Mean Squared Error: 1.0955015063133517
# [Ridge] Root Mean Squared Error: 1.096769366322266
# [Ridge] Root Mean Squared Error: 1.0975689360899639
# [Ridge] Root Mean Squared Error: 1.0980724036220775
# [Ridge] Root Mean Squared Error: 1.0983891158884826
# [Ridge] Root Mean Squared Error: 1.0985882258994983
# [Ridge] Root Mean Squared Error: 1.0987133539294802
# [Ridge] Root Mean Squared Error: 1.098791970006139
# [Ridge] Root Mean Squared Error: 1.0988413558315016
# [Ridge] Root Mean Squared Error: 1.098872376555292
# [Ridge] Root Mean Squared Error: 1.0988918604409084
# [Ridge] Root Mean Squared Error: 1.0989040976648332
# [Ridge] Root Mean Squared Error: 1.0989117833041613
# [Ridge] Root Mean Squared Error: 1.0989166102303727
# [Ridge] Root Mean Squared Error: 1.0989196417283267
# [Ridge] Root Mean Squared Error: 1.0989215456161734
# [Ridge] Root Mean Squared Error: 1.0989227413206364
# [Ridge] Root Mean Squared Error: 1.0989234922608087
# [Ridge] Root Mean Squared Error: 1.098923963874275
# [Ridge] Root Mean Squared Error: 1.098924260061731
# [Ridge] Root Mean Squared Error: 1.0989244460762648
# [Ridge] Root Mean Squared Error: 1.0989245628988842
# [Ridge] Root Mean Squared Error: 1.0989246362669216
# [Ridge] Root Mean Squared Error: 1.0989246823441983
# [Ridge] Root Mean Squared Error: 1.0989247112820755
# Computing CV fold: 6/10..
# score:  0.6541612149035124
# Root Mean Squared Error: 0.5470960721209797
# [Ridge] Root Mean Squared Error: 0.5470960721209834
# [Ridge] Root Mean Squared Error: 0.5470960721209857
# [Ridge] Root Mean Squared Error: 0.5470960721209892
# [Ridge] Root Mean Squared Error: 0.5470960721209949
# [Ridge] Root Mean Squared Error: 0.547096072121004
# [Ridge] Root Mean Squared Error: 0.5470960721210182
# [Ridge] Root Mean Squared Error: 0.547096072121041
# [Ridge] Root Mean Squared Error: 0.5470960721210775
# [Ridge] Root Mean Squared Error: 0.5470960721211354
# [Ridge] Root Mean Squared Error: 0.5470960721212276
# [Ridge] Root Mean Squared Error: 0.5470960721213742
# [Ridge] Root Mean Squared Error: 0.547096072121608
# [Ridge] Root Mean Squared Error: 0.5470960721219802
# [Ridge] Root Mean Squared Error: 0.5470960721225727
# [Ridge] Root Mean Squared Error: 0.5470960721235163
# [Ridge] Root Mean Squared Error: 0.5470960721250187
# [Ridge] Root Mean Squared Error: 0.547096072127411
# [Ridge] Root Mean Squared Error: 0.5470960721312201
# [Ridge] Root Mean Squared Error: 0.5470960721372852
# [Ridge] Root Mean Squared Error: 0.5470960721469428
# [Ridge] Root Mean Squared Error: 0.5470960721623201
# [Ridge] Root Mean Squared Error: 0.5470960721868054
# [Ridge] Root Mean Squared Error: 0.5470960722257929
# [Ridge] Root Mean Squared Error: 0.547096072287872
# [Ridge] Root Mean Squared Error: 0.5470960723867195
# [Ridge] Root Mean Squared Error: 0.5470960725441127
# [Ridge] Root Mean Squared Error: 0.5470960727947273
# [Ridge] Root Mean Squared Error: 0.5470960731937765
# [Ridge] Root Mean Squared Error: 0.5470960738291764
# [Ridge] Root Mean Squared Error: 0.547096074840913
# [Ridge] Root Mean Squared Error: 0.5470960764518861
# [Ridge] Root Mean Squared Error: 0.5470960790170157
# [Ridge] Root Mean Squared Error: 0.5470960831014403
# [Ridge] Root Mean Squared Error: 0.5470960896050321
# [Ridge] Root Mean Squared Error: 0.5470960999606718
# [Ridge] Root Mean Squared Error: 0.547096116449988
# [Ridge] Root Mean Squared Error: 0.5470961427061731
# [Ridge] Root Mean Squared Error: 0.5470961845147901
# [Ridge] Root Mean Squared Error: 0.5470962510893425
# [Ridge] Root Mean Squared Error: 0.5470963571035039
# [Ridge] Root Mean Squared Error: 0.5470965259299524
# [Ridge] Root Mean Squared Error: 0.5470967948049841
# [Ridge] Root Mean Squared Error: 0.5470972230709842
# [Ridge] Root Mean Squared Error: 0.5470979053488012
# [Ridge] Root Mean Squared Error: 0.5470989926336154
# [Ridge] Root Mean Squared Error: 0.5471007261939685
# [Ridge] Root Mean Squared Error: 0.5471034923299269
# [Ridge] Root Mean Squared Error: 0.5471079115416885
# [Ridge] Root Mean Squared Error: 0.5471149855151856
# [Ridge] Root Mean Squared Error: 0.5471263438060392
# [Ridge] Root Mean Squared Error: 0.5471446684970188
# [Ridge] Root Mean Squared Error: 0.5471744504293378
# [Ridge] Root Mean Squared Error: 0.5472233933518943
# [Ridge] Root Mean Squared Error: 0.5473051450251724
# [Ridge] Root Mean Squared Error: 0.5474448548210736
# [Ridge] Root Mean Squared Error: 0.5476909040268158
# [Ridge] Root Mean Squared Error: 0.5481401778992426
# [Ridge] Root Mean Squared Error: 0.5489923562390148
# [Ridge] Root Mean Squared Error: 0.5506624086337509
# [Ridge] Root Mean Squared Error: 0.5539939861413982
# [Ridge] Root Mean Squared Error: 0.5605943113426565
# [Ridge] Root Mean Squared Error: 0.5731544032145504
# [Ridge] Root Mean Squared Error: 0.5952308807677339
# [Ridge] Root Mean Squared Error: 0.62970325695653
# [Ridge] Root Mean Squared Error: 0.6761472707173428
# [Ridge] Root Mean Squared Error: 0.7295436046311408
# [Ridge] Root Mean Squared Error: 0.7823762642976922
# [Ridge] Root Mean Squared Error: 0.8283687047878395
# [Ridge] Root Mean Squared Error: 0.8645750648125714
# [Ridge] Root Mean Squared Error: 0.8910414954137612
# [Ridge] Root Mean Squared Error: 0.90940778979139
# [Ridge] Root Mean Squared Error: 0.921712219310604
# [Ridge] Root Mean Squared Error: 0.9297662729280483
# [Ridge] Root Mean Squared Error: 0.9349593627238253
# [Ridge] Root Mean Squared Error: 0.9382755810516002
# [Ridge] Root Mean Squared Error: 0.9403802877020356
# [Ridge] Root Mean Squared Error: 0.9417108950277755
# [Ridge] Root Mean Squared Error: 0.9425500481233016
# [Ridge] Root Mean Squared Error: 0.9430784448628852
# [Ridge] Root Mean Squared Error: 0.9434108409566666
# [Ridge] Root Mean Squared Error: 0.9436198117524128
# [Ridge] Root Mean Squared Error: 0.9437511369390502
# [Ridge] Root Mean Squared Error: 0.943833646706197
# [Ridge] Root Mean Squared Error: 0.9438854785516226
# [Ridge] Root Mean Squared Error: 0.9439180357112049
# [Ridge] Root Mean Squared Error: 0.9439384846273803
# [Ridge] Root Mean Squared Error: 0.9439513279596846
# [Ridge] Root Mean Squared Error: 0.9439593942689369
# [Ridge] Root Mean Squared Error: 0.9439644602733437
# [Ridge] Root Mean Squared Error: 0.9439676419218921
# [Ridge] Root Mean Squared Error: 0.9439696401096822
# [Ridge] Root Mean Squared Error: 0.9439708950376497
# [Ridge] Root Mean Squared Error: 0.9439716831720637
# [Ridge] Root Mean Squared Error: 0.9439721781446586
# [Ridge] Root Mean Squared Error: 0.9439724890023523
# [Ridge] Root Mean Squared Error: 0.9439726842302324
# [Ridge] Root Mean Squared Error: 0.9439728068391054
# [Ridge] Root Mean Squared Error: 0.9439728838410802
# [Ridge] Root Mean Squared Error: 0.9439729322005762
# [Ridge] Root Mean Squared Error: 0.9439729625717536
# Computing CV fold: 7/10..
# score:  0.559693309000685
# Root Mean Squared Error: 0.6131200089295172
# [Ridge] Root Mean Squared Error: 0.6131200089295045
# [Ridge] Root Mean Squared Error: 0.6131200089294973
# [Ridge] Root Mean Squared Error: 0.6131200089294851
# [Ridge] Root Mean Squared Error: 0.6131200089294663
# [Ridge] Root Mean Squared Error: 0.613120008929436
# [Ridge] Root Mean Squared Error: 0.613120008929388
# [Ridge] Root Mean Squared Error: 0.6131200089293113
# [Ridge] Root Mean Squared Error: 0.6131200089291895
# [Ridge] Root Mean Squared Error: 0.6131200089289953
# [Ridge] Root Mean Squared Error: 0.6131200089286863
# [Ridge] Root Mean Squared Error: 0.6131200089281942
# [Ridge] Root Mean Squared Error: 0.6131200089274107
# [Ridge] Root Mean Squared Error: 0.6131200089261631
# [Ridge] Root Mean Squared Error: 0.6131200089241764
# [Ridge] Root Mean Squared Error: 0.6131200089210133
# [Ridge] Root Mean Squared Error: 0.6131200089159766
# [Ridge] Root Mean Squared Error: 0.6131200089079566
# [Ridge] Root Mean Squared Error: 0.6131200088951867
# [Ridge] Root Mean Squared Error: 0.6131200088748535
# [Ridge] Root Mean Squared Error: 0.613120008842477
# [Ridge] Root Mean Squared Error: 0.6131200087909247
# [Ridge] Root Mean Squared Error: 0.6131200087088388
# [Ridge] Root Mean Squared Error: 0.6131200085781344
# [Ridge] Root Mean Squared Error: 0.6131200083700168
# [Ridge] Root Mean Squared Error: 0.6131200080386343
# [Ridge] Root Mean Squared Error: 0.6131200075109795
# [Ridge] Root Mean Squared Error: 0.6131200066708041
# [Ridge] Root Mean Squared Error: 0.6131200053330075
# [Ridge] Root Mean Squared Error: 0.6131200032028573
# [Ridge] Root Mean Squared Error: 0.6131199998110568
# [Ridge] Root Mean Squared Error: 0.6131199944103539
# [Ridge] Root Mean Squared Error: 0.613119985810914
# [Ridge] Root Mean Squared Error: 0.6131199721181898
# [Ridge] Root Mean Squared Error: 0.6131199503155417
# [Ridge] Root Mean Squared Error: 0.6131199155996645
# [Ridge] Root Mean Squared Error: 0.6131198603224345
# [Ridge] Root Mean Squared Error: 0.613119772306121
# [Ridge] Root Mean Squared Error: 0.6131196321609559
# [Ridge] Root Mean Squared Error: 0.6131194090145214
# [Ridge] Root Mean Squared Error: 0.6131190537131966
# [Ridge] Root Mean Squared Error: 0.6131184880006538
# [Ridge] Root Mean Squared Error: 0.6131175872963892
# [Ridge] Root Mean Squared Error: 0.6131161532981649
# [Ridge] Root Mean Squared Error: 0.6131138704179134
# [Ridge] Root Mean Squared Error: 0.6131102365688821
# [Ridge] Root Mean Squared Error: 0.6131044533482213
# [Ridge] Root Mean Squared Error: 0.6130952521622277
# [Ridge] Root Mean Squared Error: 0.613080619864661
# [Ridge] Root Mean Squared Error: 0.6130573682125396
# [Ridge] Root Mean Squared Error: 0.6130204642886888
# [Ridge] Root Mean Squared Error: 0.6129620046525451
# [Ridge] Root Mean Squared Error: 0.6128696833520509
# [Ridge] Root Mean Squared Error: 0.6127246068173466
# [Ridge] Root Mean Squared Error: 0.6124984472940486
# [Ridge] Root Mean Squared Error: 0.6121504672786648
# [Ridge] Root Mean Squared Error: 0.6116265428162537
# [Ridge] Root Mean Squared Error: 0.6108664207353174
# [Ridge] Root Mean Squared Error: 0.6098348701031842
# [Ridge] Root Mean Squared Error: 0.608610933581622
# [Ridge] Root Mean Squared Error: 0.6075961987742591
# [Ridge] Root Mean Squared Error: 0.6079088649546206
# [Ridge] Root Mean Squared Error: 0.6119077400448375
# [Ridge] Root Mean Squared Error: 0.623363697834456
# [Ridge] Root Mean Squared Error: 0.6462595039828026
# [Ridge] Root Mean Squared Error: 0.6818915694839356
# [Ridge] Root Mean Squared Error: 0.7266227484058909
# [Ridge] Root Mean Squared Error: 0.7733183576296252
# [Ridge] Root Mean Squared Error: 0.8153033990328469
# [Ridge] Root Mean Squared Error: 0.8490024530472048
# [Ridge] Root Mean Squared Error: 0.8739256932056721
# [Ridge] Root Mean Squared Error: 0.8913443406292274
# [Ridge] Root Mean Squared Error: 0.9030647892036221
# [Ridge] Root Mean Squared Error: 0.9107572294659232
# [Ridge] Root Mean Squared Error: 0.9157254397137145
# [Ridge] Root Mean Squared Error: 0.918901354827782
# [Ridge] Root Mean Squared Error: 0.9209183256920555
# [Ridge] Root Mean Squared Error: 0.9221939849892652
# [Ridge] Root Mean Squared Error: 0.9229986901182999
# [Ridge] Root Mean Squared Error: 0.9235054767906496
# [Ridge] Root Mean Squared Error: 0.9238243107509728
# [Ridge] Root Mean Squared Error: 0.9240247679378426
# [Ridge] Root Mean Squared Error: 0.924150747834308
# [Ridge] Root Mean Squared Error: 0.9242299011975439
# [Ridge] Root Mean Squared Error: 0.9242796253580093
# [Ridge] Root Mean Squared Error: 0.9243108589225545
# [Ridge] Root Mean Squared Error: 0.9243304766189844
# [Ridge] Root Mean Squared Error: 0.924342797935468
# [Ridge] Root Mean Squared Error: 0.924350536409253
# [Ridge] Root Mean Squared Error: 0.9243553965256736
# [Ridge] Root Mean Squared Error: 0.92435844887145
# [Ridge] Root Mean Squared Error: 0.9243603658536795
# [Ridge] Root Mean Squared Error: 0.9243615697823259
# [Ridge] Root Mean Squared Error: 0.924362325887734
# [Ridge] Root Mean Squared Error: 0.9243628007452013
# [Ridge] Root Mean Squared Error: 0.9243630989700171
# [Ridge] Root Mean Squared Error: 0.9243632862640849
# [Ridge] Root Mean Squared Error: 0.9243634038902939
# [Ridge] Root Mean Squared Error: 0.9243634777630111
# [Ridge] Root Mean Squared Error: 0.9243635241572423
# [Ridge] Root Mean Squared Error: 0.9243635532941763
# Computing CV fold: 8/10..
# score:  0.5852961825523735
# Root Mean Squared Error: 0.6299487745850568
# [Ridge] Root Mean Squared Error: 0.6299487745850545
# [Ridge] Root Mean Squared Error: 0.6299487745850529
# [Ridge] Root Mean Squared Error: 0.6299487745850507
# [Ridge] Root Mean Squared Error: 0.6299487745850469
# [Ridge] Root Mean Squared Error: 0.6299487745850413
# [Ridge] Root Mean Squared Error: 0.6299487745850322
# [Ridge] Root Mean Squared Error: 0.6299487745850174
# [Ridge] Root Mean Squared Error: 0.6299487745849939
# [Ridge] Root Mean Squared Error: 0.6299487745849569
# [Ridge] Root Mean Squared Error: 0.6299487745848977
# [Ridge] Root Mean Squared Error: 0.6299487745848035
# [Ridge] Root Mean Squared Error: 0.6299487745846533
# [Ridge] Root Mean Squared Error: 0.6299487745844141
# [Ridge] Root Mean Squared Error: 0.6299487745840336
# [Ridge] Root Mean Squared Error: 0.6299487745834274
# [Ridge] Root Mean Squared Error: 0.6299487745824625
# [Ridge] Root Mean Squared Error: 0.6299487745809257
# [Ridge] Root Mean Squared Error: 0.629948774578479
# [Ridge] Root Mean Squared Error: 0.6299487745745831
# [Ridge] Root Mean Squared Error: 0.6299487745683795
# [Ridge] Root Mean Squared Error: 0.6299487745585017
# [Ridge] Root Mean Squared Error: 0.6299487745427739
# [Ridge] Root Mean Squared Error: 0.6299487745177302
# [Ridge] Root Mean Squared Error: 0.6299487744778537
# [Ridge] Root Mean Squared Error: 0.6299487744143591
# [Ridge] Root Mean Squared Error: 0.629948774313258
# [Ridge] Root Mean Squared Error: 0.6299487741522762
# [Ridge] Root Mean Squared Error: 0.629948773895948
# [Ridge] Root Mean Squared Error: 0.6299487734878012
# [Ridge] Root Mean Squared Error: 0.629948772837917
# [Ridge] Root Mean Squared Error: 0.6299487718031195
# [Ridge] Root Mean Squared Error: 0.6299487701554343
# [Ridge] Root Mean Squared Error: 0.6299487675318667
# [Ridge] Root Mean Squared Error: 0.629948763354439
# [Ridge] Root Mean Squared Error: 0.6299487567028775
# [Ridge] Root Mean Squared Error: 0.629948746111926
# [Ridge] Root Mean Squared Error: 0.6299487292486824
# [Ridge] Root Mean Squared Error: 0.6299487023990137
# [Ridge] Root Mean Squared Error: 0.6299486596502583
# [Ridge] Root Mean Squared Error: 0.6299485915910494
# [Ridge] Root Mean Squared Error: 0.629948483244103
# [Ridge] Root Mean Squared Error: 0.6299483107823232
# [Ridge] Root Mean Squared Error: 0.6299480363194099
# [Ridge] Root Mean Squared Error: 0.6299475996644607
# [Ridge] Root Mean Squared Error: 0.6299469053182383
# [Ridge] Root Mean Squared Error: 0.6299458020849985
# [Ridge] Root Mean Squared Error: 0.6299440514129601
# [Ridge] Root Mean Squared Error: 0.6299412790196969
# [Ridge] Root Mean Squared Error: 0.6299369030183071
# [Ridge] Root Mean Squared Error: 0.6299300324940422
# [Ridge] Root Mean Squared Error: 0.6299193388484697
# [Ridge] Root Mean Squared Error: 0.6299029335106244
# [Ridge] Root Mean Squared Error: 0.6298783797870302
# [Ridge] Root Mean Squared Error: 0.6298432243883846
# [Ridge] Root Mean Squared Error: 0.629797099605322
# [Ridge] Root Mean Squared Error: 0.6297480818696773
# [Ridge] Root Mean Squared Error: 0.6297297832933314
# [Ridge] Root Mean Squared Error: 0.6298437142948081
# [Ridge] Root Mean Squared Error: 0.6303560680123448
# [Ridge] Root Mean Squared Error: 0.6318957506966203
# [Ridge] Root Mean Squared Error: 0.6357911194712227
# [Ridge] Root Mean Squared Error: 0.6444521751845809
# [Ridge] Root Mean Squared Error: 0.6613320883282304
# [Ridge] Root Mean Squared Error: 0.6896401796806035
# [Ridge] Root Mean Squared Error: 0.7297612960180899
# [Ridge] Root Mean Squared Error: 0.7775695099895159
# [Ridge] Root Mean Squared Error: 0.8260465709520034
# [Ridge] Root Mean Squared Error: 0.8689345805033972
# [Ridge] Root Mean Squared Error: 0.9030484282186683
# [Ridge] Root Mean Squared Error: 0.9281487046469915
# [Ridge] Root Mean Squared Error: 0.945638443579657
# [Ridge] Root Mean Squared Error: 0.9573856957220591
# [Ridge] Root Mean Squared Error: 0.9650873841929696
# [Ridge] Root Mean Squared Error: 0.9700582679058152
# [Ridge] Root Mean Squared Error: 0.973234589050609
# [Ridge] Root Mean Squared Error: 0.9752513035647524
# [Ridge] Root Mean Squared Error: 0.9765265978561143
# [Ridge] Root Mean Squared Error: 0.9773309927044831
# [Ridge] Root Mean Squared Error: 0.9778375524006557
# [Ridge] Root Mean Squared Error: 0.9781562311122168
# [Ridge] Root Mean Squared Error: 0.978356585779846
# [Ridge] Root Mean Squared Error: 0.9784824993096319
# [Ridge] Root Mean Squared Error: 0.9785616102105232
# [Ridge] Root Mean Squared Error: 0.9786113073947728
# [Ridge] Root Mean Squared Error: 0.9786425238957059
# [Ridge] Root Mean Squared Error: 0.9786621308276563
# [Ridge] Root Mean Squared Error: 0.9786744453647855
# [Ridge] Root Mean Squared Error: 0.9786821795734646
# [Ridge] Root Mean Squared Error: 0.978687037008326
# [Ridge] Root Mean Squared Error: 0.9786900876688427
# [Ridge] Root Mean Squared Error: 0.9786920035922212
# [Ridge] Root Mean Squared Error: 0.9786932068556975
# [Ridge] Root Mean Squared Error: 0.9786939625432881
# [Ridge] Root Mean Squared Error: 0.9786944371383255
# [Ridge] Root Mean Squared Error: 0.9786947351983167
# [Ridge] Root Mean Squared Error: 0.9786949223888656
# [Ridge] Root Mean Squared Error: 0.9786950399500599
# [Ridge] Root Mean Squared Error: 0.9786951137819452
# [Ridge] Root Mean Squared Error: 0.9786951601505325
# [Ridge] Root Mean Squared Error: 0.9786951892713612
# Computing CV fold: 9/10..
# score:  0.5739809755383991
# Root Mean Squared Error: 0.6357267776059102
# [Ridge] Root Mean Squared Error: 0.6357267776059071
# [Ridge] Root Mean Squared Error: 0.6357267776059052
# [Ridge] Root Mean Squared Error: 0.6357267776059022
# [Ridge] Root Mean Squared Error: 0.6357267776058975
# [Ridge] Root Mean Squared Error: 0.6357267776058901
# [Ridge] Root Mean Squared Error: 0.6357267776058781
# [Ridge] Root Mean Squared Error: 0.6357267776058589
# [Ridge] Root Mean Squared Error: 0.6357267776058286
# [Ridge] Root Mean Squared Error: 0.6357267776057804
# [Ridge] Root Mean Squared Error: 0.6357267776057034
# [Ridge] Root Mean Squared Error: 0.6357267776055809
# [Ridge] Root Mean Squared Error: 0.635726777605386
# [Ridge] Root Mean Squared Error: 0.6357267776050756
# [Ridge] Root Mean Squared Error: 0.635726777604581
# [Ridge] Root Mean Squared Error: 0.6357267776037938
# [Ridge] Root Mean Squared Error: 0.6357267776025404
# [Ridge] Root Mean Squared Error: 0.6357267776005446
# [Ridge] Root Mean Squared Error: 0.6357267775973666
# [Ridge] Root Mean Squared Error: 0.6357267775923063
# [Ridge] Root Mean Squared Error: 0.635726777584249
# [Ridge] Root Mean Squared Error: 0.6357267775714195
# [Ridge] Root Mean Squared Error: 0.6357267775509913
# [Ridge] Root Mean Squared Error: 0.6357267775184637
# [Ridge] Root Mean Squared Error: 0.6357267774666707
# [Ridge] Root Mean Squared Error: 0.6357267773842015
# [Ridge] Root Mean Squared Error: 0.6357267772528873
# [Ridge] Root Mean Squared Error: 0.635726777043798
# [Ridge] Root Mean Squared Error: 0.6357267767108687
# [Ridge] Root Mean Squared Error: 0.6357267761807516
# [Ridge] Root Mean Squared Error: 0.6357267753366559
# [Ridge] Root Mean Squared Error: 0.635726773992619
# [Ridge] Root Mean Squared Error: 0.6357267718525373
# [Ridge] Root Mean Squared Error: 0.6357267684449355
# [Ridge] Root Mean Squared Error: 0.6357267630191029
# [Ridge] Root Mean Squared Error: 0.6357267543797278
# [Ridge] Root Mean Squared Error: 0.6357267406236145
# [Ridge] Root Mean Squared Error: 0.6357267187205368
# [Ridge] Root Mean Squared Error: 0.6357266838460244
# [Ridge] Root Mean Squared Error: 0.6357266283194404
# [Ridge] Root Mean Squared Error: 0.6357265399142951
# [Ridge] Root Mean Squared Error: 0.6357263991708149
# [Ridge] Root Mean Squared Error: 0.6357261751244652
# [Ridge] Root Mean Squared Error: 0.6357258185240093
# [Ridge] Root Mean Squared Error: 0.6357252510820546
# [Ridge] Root Mean Squared Error: 0.6357243484838816
# [Ridge] Root Mean Squared Error: 0.6357229136494483
# [Ridge] Root Mean Squared Error: 0.63572063496139
# [Ridge] Root Mean Squared Error: 0.6357170217840877
# [Ridge] Root Mean Squared Error: 0.6357113069329778
# [Ridge] Root Mean Squared Error: 0.6357023043707987
# [Ridge] Root Mean Squared Error: 0.6356882153914881
# [Ridge] Root Mean Squared Error: 0.6356664024169716
# [Ridge] Root Mean Squared Error: 0.6356332350161328
# [Ridge] Root Mean Squared Error: 0.6355843565934636
# [Ridge] Root Mean Squared Error: 0.6355163634613442
# [Ridge] Root Mean Squared Error: 0.6354324884370041
# [Ridge] Root Mean Squared Error: 0.6353586231913056
# [Ridge] Root Mean Squared Error: 0.6353840244367304
# [Ridge] Root Mean Squared Error: 0.6357556863508707
# [Ridge] Root Mean Squared Error: 0.6370734267896261
# [Ridge] Root Mean Squared Error: 0.6406249234591458
# [Ridge] Root Mean Squared Error: 0.6487730636177969
# [Ridge] Root Mean Squared Error: 0.6649392097227855
# [Ridge] Root Mean Squared Error: 0.692355067704144
# [Ridge] Root Mean Squared Error: 0.7315040759794594
# [Ridge] Root Mean Squared Error: 0.7783958851252697
# [Ridge] Root Mean Squared Error: 0.8261122385947274
# [Ridge] Root Mean Squared Error: 0.8684269940095908
# [Ridge] Root Mean Squared Error: 0.9021366785160153
# [Ridge] Root Mean Squared Error: 0.9269640694763226
# [Ridge] Root Mean Squared Error: 0.9442745193248352
# [Ridge] Root Mean Squared Error: 0.9559059628251669
# [Ridge] Root Mean Squared Error: 0.9635336332827595
# [Ridge] Root Mean Squared Error: 0.968457519160302
# [Ridge] Root Mean Squared Error: 0.9716041210718379
# [Ridge] Root Mean Squared Error: 0.9736020906148494
# [Ridge] Root Mean Squared Error: 0.9748655807306525
# [Ridge] Root Mean Squared Error: 0.97566254965919
# [Ridge] Root Mean Squared Error: 0.9761644407059938
# [Ridge] Root Mean Squared Error: 0.9764801854142559
# [Ridge] Root Mean Squared Error: 0.9766786966708046
# [Ridge] Root Mean Squared Error: 0.9768034521803534
# [Ridge] Root Mean Squared Error: 0.9768818356907285
# [Ridge] Root Mean Squared Error: 0.9769310760051775
# [Ridge] Root Mean Squared Error: 0.9769620055598811
# [Ridge] Root Mean Squared Error: 0.9769814322738691
# [Ridge] Root Mean Squared Error: 0.9769936336259595
# [Ridge] Root Mean Squared Error: 0.9770012967499894
# [Ridge] Root Mean Squared Error: 0.9770061095411672
# [Ridge] Root Mean Squared Error: 0.977009132163971
# [Ridge] Root Mean Squared Error: 0.9770110304787787
# [Ridge] Root Mean Squared Error: 0.9770122226835314
# [Ridge] Root Mean Squared Error: 0.9770129714259104
# [Ridge] Root Mean Squared Error: 0.9770134416591482
# [Ridge] Root Mean Squared Error: 0.9770137369798003
# [Ridge] Root Mean Squared Error: 0.9770139224499637
# [Ridge] Root Mean Squared Error: 0.9770140389307056
# [Ridge] Root Mean Squared Error: 0.9770141120840352
# [Ridge] Root Mean Squared Error: 0.9770141580264697
# [Ridge] Root Mean Squared Error: 0.9770141868796622
# Computing CV fold: 10/10..
# score:  0.44081447053221595
# Root Mean Squared Error: 1.0464707723680633
# [Ridge] Root Mean Squared Error: 1.046470772368083
# [Ridge] Root Mean Squared Error: 1.0464707723680946
# [Ridge] Root Mean Squared Error: 1.0464707723681133
# [Ridge] Root Mean Squared Error: 1.0464707723681428
# [Ridge] Root Mean Squared Error: 1.0464707723681896
# [Ridge] Root Mean Squared Error: 1.0464707723682645
# [Ridge] Root Mean Squared Error: 1.0464707723683833
# [Ridge] Root Mean Squared Error: 1.0464707723685729
# [Ridge] Root Mean Squared Error: 1.0464707723688746
# [Ridge] Root Mean Squared Error: 1.0464707723693547
# [Ridge] Root Mean Squared Error: 1.0464707723701197
# [Ridge] Root Mean Squared Error: 1.0464707723713373
# [Ridge] Root Mean Squared Error: 1.0464707723732765
# [Ridge] Root Mean Squared Error: 1.0464707723763638
# [Ridge] Root Mean Squared Error: 1.04647077238128
# [Ridge] Root Mean Squared Error: 1.046470772389108
# [Ridge] Root Mean Squared Error: 1.0464707724015723
# [Ridge] Root Mean Squared Error: 1.0464707724214188
# [Ridge] Root Mean Squared Error: 1.0464707724530207
# [Ridge] Root Mean Squared Error: 1.0464707725033393
# [Ridge] Root Mean Squared Error: 1.046470772583461
# [Ridge] Root Mean Squared Error: 1.046470772711037
# [Ridge] Root Mean Squared Error: 1.0464707729141745
# [Ridge] Root Mean Squared Error: 1.0464707732376266
# [Ridge] Root Mean Squared Error: 1.046470773752654
# [Ridge] Root Mean Squared Error: 1.046470774572723
# [Ridge] Root Mean Squared Error: 1.0464707758785052
# [Ridge] Root Mean Squared Error: 1.0464707779576792
# [Ridge] Root Mean Squared Error: 1.0464707812683125
# [Ridge] Root Mean Squared Error: 1.0464707865397773
# [Ridge] Root Mean Squared Error: 1.0464707949334402
# [Ridge] Root Mean Squared Error: 1.046470808298526
# [Ridge] Root Mean Squared Error: 1.0464708295795246
# [Ridge] Root Mean Squared Error: 1.046470863464899
# [Ridge] Root Mean Squared Error: 1.0464709174200135
# [Ridge] Root Mean Squared Error: 1.046471003331854
# [Ridge] Root Mean Squared Error: 1.0464711401279012
# [Ridge] Root Mean Squared Error: 1.0464713579461515
# [Ridge] Root Mean Squared Error: 1.0464717047750582
# [Ridge] Root Mean Squared Error: 1.0464722570264189
# [Ridge] Root Mean Squared Error: 1.0464731363709663
# [Ridge] Root Mean Squared Error: 1.046474536546828
# [Ridge] Root Mean Squared Error: 1.0464767660498078
# [Ridge] Root Mean Squared Error: 1.0464803161176015
# [Ridge] Root Mean Squared Error: 1.0464859690032424
# [Ridge] Root Mean Squared Error: 1.0464949704361624
# [Ridge] Root Mean Squared Error: 1.0465093043786031
# [Ridge] Root Mean Squared Error: 1.046532130893796
# [Ridge] Root Mean Squared Error: 1.0465684843106178
# [Ridge] Root Mean Squared Error: 1.0466263873020403
# [Ridge] Root Mean Squared Error: 1.0467186308343823
# [Ridge] Root Mean Squared Error: 1.046865623331736
# [Ridge] Root Mean Squared Error: 1.0470999641985446
# [Ridge] Root Mean Squared Error: 1.0474738150575507
# [Ridge] Root Mean Squared Error: 1.0480708443932734
# [Ridge] Root Mean Squared Error: 1.049025703677091
# [Ridge] Root Mean Squared Error: 1.050555933802746
# [Ridge] Root Mean Squared Error: 1.0530140741419054
# [Ridge] Root Mean Squared Error: 1.0569706276036972
# [Ridge] Root Mean Squared Error: 1.0633358950822775
# [Ridge] Root Mean Squared Error: 1.073501999957968
# [Ridge] Root Mean Squared Error: 1.0893971318844422
# [Ridge] Root Mean Squared Error: 1.113175983334629
# [Ridge] Root Mean Squared Error: 1.146209086648199
# [Ridge] Root Mean Squared Error: 1.1875720639319982
# [Ridge] Root Mean Squared Error: 1.2333303161803344
# [Ridge] Root Mean Squared Error: 1.2778726436649785
# [Ridge] Root Mean Squared Error: 1.3164608538655298
# [Ridge] Root Mean Squared Error: 1.3468362727193806
# [Ridge] Root Mean Squared Error: 1.3690710059636215
# [Ridge] Root Mean Squared Error: 1.3845238344621469
# [Ridge] Root Mean Squared Error: 1.3948888876843113
# [Ridge] Root Mean Squared Error: 1.4016793729536539
# [Ridge] Root Mean Squared Error: 1.4060603156042661
# [Ridge] Root Mean Squared Error: 1.4088589936418878
# [Ridge] Root Mean Squared Error: 1.4106356769114323
# [Ridge] Root Mean Squared Error: 1.4117590855850388
# [Ridge] Root Mean Squared Error: 1.412467639891601
# [Ridge] Root Mean Squared Error: 1.4129138300040214
# [Ridge] Root Mean Squared Error: 1.413194524116484
# [Ridge] Root Mean Squared Error: 1.4133709954055824
# [Ridge] Root Mean Squared Error: 1.4134818984458888
# [Ridge] Root Mean Squared Error: 1.4135515779682348
# [Ridge] Root Mean Squared Error: 1.4135953502540721
# [Ridge] Root Mean Squared Error: 1.4136228450684276
# [Ridge] Root Mean Squared Error: 1.4136401144054047
# [Ridge] Root Mean Squared Error: 1.4136509607593102
# [Ridge] Root Mean Squared Error: 1.4136577728645408
# [Ridge] Root Mean Squared Error: 1.413662051175156
# [Ridge] Root Mean Squared Error: 1.4136647381222966
# [Ridge] Root Mean Squared Error: 1.4136664256205225
# [Ridge] Root Mean Squared Error: 1.413667485425339
# [Ridge] Root Mean Squared Error: 1.413668151016313
# [Ridge] Root Mean Squared Error: 1.4136685690278927
# [Ridge] Root Mean Squared Error: 1.413668831551762
# [Ridge] Root Mean Squared Error: 1.413668996424566
# [Ridge] Root Mean Squared Error: 1.4136690999695565
# [Ridge] Root Mean Squared Error: 1.4136691649988535
# [Ridge] Root Mean Squared Error: 1.4136692058391573
# [Ridge] Root Mean Squared Error: 1.4136692314880626

# %%
X_train_perfect, X_test_perfect, y_train_perfect, y_test_perfect = X_train, X_test, y_train, y_test

# %%
# %store X_train_perfect
# %store X_test_perfect
# %store y_train_perfect 
# %store y_test_perfect
# %store X
# %store y
# Out:
# Stored 'X_train_perfect' (ndarray)
# Stored 'X_test_perfect' (ndarray)
# Stored 'y_train_perfect' (Series)
# Stored 'y_test_perfect' (Series)
# Stored 'X' (ndarray)
# Stored 'y' (Series)
